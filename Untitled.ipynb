# %%
import os
import pandas as pd

# %%
# importing data
df = pd.read_excel('Resources/CO_House_prices.xlsx')
df.head()
# Out:
#         CountyName      1997    1997.1    1997.2    1997.3    1997.4  \
# 0    Denver County  137645.0  139004.0  140457.0  141496.0  142674.0
# 1   El Paso County  139699.0  140358.0  141062.0  141691.0  142171.0
# 2  Arapahoe County  130120.0  130543.0  131002.0  131724.0  132453.0
# 3   Larimer County  161433.0  161747.0  162018.0  162237.0  162340.0
# 4    Pueblo County   87839.0   88350.0   88838.0   89398.0   89961.0
#
#      1997.5    1997.6    1997.7    1997.8  ...    2016.2    2016.3    2016.4  \
# 0  143911.0  145010.0  145936.0  146793.0  ...  363663.0  365549.0  368018.0
# 1  142477.0  142854.0  143113.0  143509.0  ...  234461.0  236917.0  238308.0
# 2  133070.0  133495.0  133998.0  134750.0  ...  278440.0  281270.0  284134.0
# 3  162536.0  162901.0  163436.0  163978.0  ...  342499.0  345621.0  347420.0
# 4   90483.0   90888.0   91280.0   91726.0  ...  136237.0  137034.0  138265.0
#
#      2016.5    2016.6    2016.7    2016.8    2016.9   2016.10   2016.11
# ...

# %%
df.groupby(['CountyName']).mean()
# Out:
#                             1997         1997.1         1997.2         1997.3  \
# CountyName
# Adams County       124128.133333  124716.466667  125288.666667  125876.133333
# Alamosa County      67003.500000   67262.000000   67488.000000   67377.500000
# Arapahoe County    265646.357143  266803.428571  267554.571429  268416.928571
# Archuleta County             NaN            NaN            NaN            NaN
# Baca County                  NaN            NaN            NaN            NaN
# ...                          ...            ...            ...            ...
# Summit County                NaN            NaN            NaN            NaN
# Teller County      100278.800000  100695.400000  101434.200000  102118.400000
# Washington County            NaN            NaN            NaN            NaN
# Weld County        162607.777778  162711.333333  163195.888889  163515.481481
# Yuma County                  NaN            NaN            NaN            NaN
#
# ...

# %%
county_list = df.CountyName.unique()
county_list
# Out:
# array(['Denver County', 'El Paso County', 'Arapahoe County',
#        'Larimer County', 'Pueblo County', 'Jefferson County',
#        'Adams County', 'Boulder County', 'Mesa County', 'Douglas County',
#        'Weld County', 'Broomfield County', 'La Plata County',
#        'Montrose County', 'Fremont County', 'Routt County',
#        'Logan County', 'Morgan County', 'Montezuma County',
#        'Alamosa County', 'Garfield County', 'Delta County',
#        'Teller County', 'Moffat County', 'Elbert County', 'Eagle County',
#        'Archuleta County', 'Summit County', 'Pitkin County',
#        'Otero County', 'Gunnison County', 'Chaffee County',
#        'Prowers County', 'Lake County', 'Park County',
#        'Rio Grande County', 'Grand County', 'Kit Carson County',
#        'Bent County', 'Clear Creek County', 'Yuma County',
#        'Huerfano County', 'Rio Blanco County', 'Custer County',
#        'Las Animas County', 'Phillips County', 'Ouray County',
# ...

# %%
El_Paso_df[1997]
# Out:
# 1      139699.0
# 27     114305.0
# 29     124579.0
# 34     238017.0
# 41     163244.0
# 52          NaN
# 81     144184.0
# 102         NaN
# 111    160237.0
# 117    212178.0
# 120         NaN
# 124     96762.0
# 194         NaN
# 200         NaN
# 219    150168.0
# 274     75436.0
# 290    118242.0
# Name: 1997, dtype: float64
