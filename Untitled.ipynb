# %%
import os
import pandas as pd

# %%
# importing data
house_df = pd.read_excel('Resources/clean_House_prices.xlsx')
house_df.head()
# Out:
#         CountyName           1997           1998           1999  \
# 0    Denver County  144211.083333  157625.333333  175471.916667
# 1   El Paso County  142508.916667  147672.916667  155935.500000
# 2  Arapahoe County  133396.916667  143271.666667  158078.333333
# 3   Larimer County  163194.666667  168924.833333  181416.916667
# 4    Pueblo County   90495.750000   95448.666667  102374.000000
#
#             2000           2001           2002           2003           2004  \
# 0  202976.333333  232443.583333  246901.750000  249635.461538  254793.583333
# 1  163330.083333  177515.833333  186842.166667  192284.461538  198514.916667
# 2  180677.916667  206261.916667  215658.250000  218679.153846  220339.000000
# 3  196578.083333  218750.500000  233787.166667  239067.615385  245698.583333
# 4  108664.583333  111731.000000  114387.333333  118079.000000  123091.500000
#
#             2005  ...           2007           2008           2009  \
# ...

# %%
cleaned_house_df = house_df.groupby(['CountyName']).mean()
cleaned_house_df
# Out:
#                             1997           1998           1999           2000  \
# CountyName
# Adams County       128133.405556  138042.472222  153253.533333  175973.177778
# Alamosa County      67630.875000   66069.177778   69118.444444   73833.472222
# Arapahoe County    269897.303571  281234.130952  314151.220238  360547.946429
# Archuleta County             NaN            NaN            NaN            NaN
# Baca County                  NaN            NaN            NaN            NaN
# ...                          ...            ...            ...            ...
# Summit County                NaN            NaN  223403.226852  250463.111111
# Teller County      103601.833333  109636.100000  117109.483333  127863.416667
# Washington County            NaN            NaN            NaN            NaN
# Weld County        164598.623457  173410.191358  190099.425926  205095.793210
# Yuma County                  NaN            NaN            NaN            NaN
#
# ...

# %%
# Create CountyName and CountyID column
cleaned_house_df.reset_index(inplace=True)
cleaned_house_df.reset_index(inplace=True)
cleaned_house_df = cleaned_house_df.rename(columns={"index": "CountyID"})

# %%
# Save house prices df in to data_visualize for visualizing purpose
cleaned_house_df.to_csv('Resources/data_visualize.csv', index=False)
cleaned_house_df
# Out:
#     CountyID         CountyName           1997           1998           1999  \
# 0          0       Adams County  128133.405556  138042.472222  153253.533333
# 1          1     Alamosa County   67630.875000   66069.177778   69118.444444
# 2          2    Arapahoe County  269897.303571  281234.130952  314151.220238
# 3          3   Archuleta County            NaN            NaN            NaN
# 4          4        Baca County            NaN            NaN            NaN
# ..       ...                ...            ...            ...            ...
# 59        59      Summit County            NaN            NaN  223403.226852
# 60        60      Teller County  103601.833333  109636.100000  117109.483333
# 61        61  Washington County            NaN            NaN            NaN
# 62        62        Weld County  164598.623457  173410.191358  190099.425926
# 63        63        Yuma County            NaN            NaN            NaN
#
# ...

# %%
# create a dataframe with CountyName and CountyID
counties_df = cleaned_house_df[['CountyID', 'CountyName']]
counties_df
# Out:
#     CountyID         CountyName
# 0          0       Adams County
# 1          1     Alamosa County
# 2          2    Arapahoe County
# 3          3   Archuleta County
# 4          4        Baca County
# ..       ...                ...
# 59        59      Summit County
# 60        60      Teller County
# 61        61  Washington County
# 62        62        Weld County
# 63        63        Yuma County
#
# [64 rows x 2 columns]

# %%
counties_list = cleaned_house_df[['CountyName']]
counties_list
# Out:
#            CountyName
# 0        Adams County
# 1      Alamosa County
# 2     Arapahoe County
# 3    Archuleta County
# 4         Baca County
# ..                ...
# 59      Summit County
# 60      Teller County
# 61  Washington County
# 62        Weld County
# 63        Yuma County
#
# [64 rows x 1 columns]

# %%
# Import income data
income_df = pd.read_excel('Resources/CO_income.xlsx')
income_df.head()
# Out:
#   areatyname         areaname  periodyear  periodtype pertypdesc  \
# 0     County  La Plata County        1997           1     Annual
# 1     County  Montrose County        1997           1     Annual
# 2     County   Fremont County        1997           1     Annual
# 3     County  Arapahoe County        1997           1     Annual
# 4     County  Huerfano County        1997           1     Annual
#
#                                           incdesc income  population
# 0  Median Household Income - United States Census  36822     41654.0
# 1  Median Household Income - United States Census  32312     31460.0
# 2  Median Household Income - United States Census  29939     43825.0
# 3  Median Household Income - United States Census  50748    462681.0
# 4  Median Household Income - United States Census  21389      7553.0

# %%
# Check if all values in CountyName are in income data
for county in counties_list:
    if county not in income_df.areaname:
        print(f"The {county} is not in the income data")
# Out:
# The CountyName is not in the income data

# %%
# Check if all counties in areaname of income data are in house data
# x = 0
# for county in income_df.areaname:
#     x += 1
#     if county not in counties_list:
#         print(f"The {county} is not in the house price data. Index {x}")
if income_df.areaname[1] not in counties_list:
    print(f"{income_df.areaname[1]}")
# Out:
# Montrose County

# %%
# Merge two datafram
merged_df = cleaned_house_df.merge(income_df, left_on='CountyName', right_on='areaname')
merged_df.head()
# Out:
#    CountyID    CountyName           1997           1998           1999  \
# 0         0  Adams County  128133.405556  138042.472222  153253.533333
# 1         0  Adams County  128133.405556  138042.472222  153253.533333
# 2         0  Adams County  128133.405556  138042.472222  153253.533333
# 3         0  Adams County  128133.405556  138042.472222  153253.533333
# 4         0  Adams County  128133.405556  138042.472222  153253.533333
#
#             2000           2001           2002           2003           2004  \
# 0  175973.177778  201303.355556  213591.866667  218562.133333  219396.283333
# 1  175973.177778  201303.355556  213591.866667  218562.133333  219396.283333
# 2  175973.177778  201303.355556  213591.866667  218562.133333  219396.283333
# 3  175973.177778  201303.355556  213591.866667  218562.133333  219396.283333
# 4  175973.177778  201303.355556  213591.866667  218562.133333  219396.283333
#
# ...

# %%
column_list = merged_df.columns
column_list
# Out:
# Index([  'CountyID', 'CountyName',         1997,         1998,         1999,
#                2000,         2001,         2002,         2003,         2004,
#                2005,         2006,         2007,         2008,         2009,
#                2010,         2011,         2012,         2013,         2014,
#                2015,         2016, 'areatyname',   'areaname', 'periodyear',
#        'periodtype', 'pertypdesc',    'incdesc',     'income', 'population'],
#       dtype='object')

# %%
cleaned_house_df.head()
# Out:
#    CountyID        CountyName           1997           1998           1999  \
# 0         0      Adams County  128133.405556  138042.472222  153253.533333
# 1         1    Alamosa County   67630.875000   66069.177778   69118.444444
# 2         2   Arapahoe County  269897.303571  281234.130952  314151.220238
# 3         3  Archuleta County            NaN            NaN            NaN
# 4         4       Baca County            NaN            NaN            NaN
#
#             2000           2001           2002           2003           2004  \
# 0  175973.177778  201303.355556  213591.866667  218562.133333  219396.283333
# 1   73833.472222   77740.000000   82612.388889   85057.948718   88569.777778
# 2  360547.946429  409783.434524  428854.696429  434402.703297  440531.523810
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
# ...

# %%
period_list = income_df.periodyear.unique()
period_list
# Out:
# array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], dtype=int64)
