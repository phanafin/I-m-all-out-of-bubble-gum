# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Read the CSV

# %%
pricing_out_df = pd.read_csv('pricing_out.csv')
pricing_out_df.head()
# Out:
#    Unnamed: 0  year county                                        Description  \
# 0           0  2010  Adams         Agriculture, forestry, fishing and hunting
# 1           1  2010  Adams      Mining, quarrying, and oil and gas extraction
# 2           2  2010  Adams                                      Manufacturing
# 3           3  2010  Adams  Educational services, health care, and social ...
# 4           4  2010  Adams  Arts, entertainment, recreation, accommodation...
#
#   GDP_Change  House_price  Income  interest_rate  lending_limit  periods  \
# 0       31.9    186966.95   52785         0.0025           0.25      360
# 1        1.4    186966.95   52785         0.0025           0.25      360
# 2       -3.5    186966.95   52785         0.0025           0.25      360
# 3        6.5    186966.95   52785         0.0025           0.25      360
# 4        2.5    186966.95   52785         0.0025           0.25      360
#
#    suggest_payment  suggest_income priced_out
# 0       788.260203     37836.48974          N
# 1       788.260203     37836.48974          N
# 2       788.260203     37836.48974          N
# 3       788.260203     37836.48974          N
# 4       788.260203     37836.48974          N

# %%
pricing_out_df.drop(columns=['Unnamed: 0'], inplace=True)
pricing_out_df.head()
# Out:
#    year county                                        Description GDP_Change  \
# 0  2010  Adams         Agriculture, forestry, fishing and hunting       31.9
# 1  2010  Adams      Mining, quarrying, and oil and gas extraction        1.4
# 2  2010  Adams                                      Manufacturing       -3.5
# 3  2010  Adams  Educational services, health care, and social ...        6.5
# 4  2010  Adams  Arts, entertainment, recreation, accommodation...        2.5
#
#    House_price  Income  interest_rate  lending_limit  periods  \
# 0    186966.95   52785         0.0025           0.25      360
# 1    186966.95   52785         0.0025           0.25      360
# 2    186966.95   52785         0.0025           0.25      360
# 3    186966.95   52785         0.0025           0.25      360
# 4    186966.95   52785         0.0025           0.25      360
#
#    suggest_payment  suggest_income priced_out
# 0       788.260203     37836.48974          N
# 1       788.260203     37836.48974          N
# 2       788.260203     37836.48974          N
# 3       788.260203     37836.48974          N
# 4       788.260203     37836.48974          N

# %%
#drop rows with string values in GDP_Change column
pricing_out_df = pricing_out_df[~pricing_out_df['GDP_Change'].isin(['(D)', '(NM)'])]

# %%
# Change House_price to an integer
pricing_out_df['House_price'] = pricing_out_df['House_price'].astype(int)

# %% [markdown]
# # Split the Data into Training and Testing

# %%
#Define target variable
target= 'priced_out'

# Create our features
X = pricing_out_df.drop(columns='priced_out')
X = pd.get_dummies(X)


# Create our target
y = pricing_out_df.loc[:, target].copy()

# %%
X.describe()
# Out:
#               year    House_price         Income  interest_rate  \
# count  1829.000000    1829.000000    1829.000000   1.829000e+03
# mean   2013.054128  209293.217059   52622.390377   2.500000e-03
# std       2.012766  129327.088424   15236.321562   8.242190e-18
# min    2010.000000   33937.000000   26075.000000   2.500000e-03
# 25%    2011.000000  110758.000000   41730.000000   2.500000e-03
# 50%    2013.000000  188749.000000   48934.000000   2.500000e-03
# 75%    2015.000000  275615.000000   61501.000000   2.500000e-03
# max    2016.000000  778772.000000  112399.000000   2.500000e-03
#
#        lending_limit  periods  suggest_payment  suggest_income  county_Adams  \
# count        1829.00   1829.0      1829.000000     1829.000000   1829.000000
# mean            0.25    360.0       882.390676    42354.752430      0.019683
# std             0.00      0.0       545.248211    26171.914119      0.138946
# min             0.25    360.0       143.081242     6867.899595      0.000000
# 25%             0.25    360.0       466.961250    22414.139990      0.000000
# 50%             0.25    360.0       795.773515    38197.128710      0.000000
# 75%             0.25    360.0      1162.005539    55776.265850      0.000000
# max             0.25    360.0      3283.338100   157600.228800      1.000000
#
#        county_Alamosa  ...  GDP_Change_9.5  GDP_Change_9.6  GDP_Change_9.7  \
# count     1829.000000  ...     1829.000000     1829.000000     1829.000000
# mean         0.022963  ...        0.001093        0.001640        0.003827
# std          0.149828  ...        0.033059        0.040478        0.061763
# min          0.000000  ...        0.000000        0.000000        0.000000
# 25%          0.000000  ...        0.000000        0.000000        0.000000
# 50%          0.000000  ...        0.000000        0.000000        0.000000
# 75%          0.000000  ...        0.000000        0.000000        0.000000
# max          1.000000  ...        1.000000        1.000000        1.000000
#
#        GDP_Change_9.8  GDP_Change_9.9  GDP_Change_92.8  GDP_Change_937.8  \
# count     1829.000000     1829.000000      1829.000000       1829.000000
# mean         0.002187        0.001640         0.000547          0.000547
# std          0.046727        0.040478         0.023383          0.023383
# min          0.000000        0.000000         0.000000          0.000000
# 25%          0.000000        0.000000         0.000000          0.000000
# 50%          0.000000        0.000000         0.000000          0.000000
# 75%          0.000000        0.000000         0.000000          0.000000
# max          1.000000        1.000000         1.000000          1.000000
#
#        GDP_Change_98.2  GDP_Change_989.1  GDP_Change_99.3
# count      1829.000000       1829.000000      1829.000000
# mean          0.000547          0.000547         0.000547
# std           0.023383          0.023383         0.023383
# min           0.000000          0.000000         0.000000
# 25%           0.000000          0.000000         0.000000
# 50%           0.000000          0.000000         0.000000
# 75%           0.000000          0.000000         0.000000
# max           1.000000          1.000000         1.000000
#
# [8 rows x 796 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# N    1180
# Y     649
# Name: priced_out, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier 

# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

eec_model = EasyEnsembleClassifier(n_estimators=100, random_state=1)
eec_model.fit(X_train, y_train)
eec_y_pred = eec_model.predict(X_test)

# %%
# Calculated the balanced accuracy score

balanced_accuracy_score(y_test, eec_y_pred)
# Out:
# 1.0

# %%
# Display the confusion matrix
# Calculating the confusion matrix.
eec_cm = confusion_matrix(y_test, eec_y_pred)

# Create a DataFrame from the confusion matrix.
eec_cm_df = pd.DataFrame(
    eec_cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

eec_cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          283            0
# Actual 1            0          175

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, eec_y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           N       1.00      1.00      1.00      1.00      1.00      1.00       283
#           Y       1.00      1.00      1.00      1.00      1.00      1.00       175
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00       458
